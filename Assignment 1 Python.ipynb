# %% [raw]
# 1. Explain the key features of Python that make it a popular choice for programming.

# %% [raw]
# Ans: Python is a programming language that is widely used in industries due to its versatility, simplicity and efficiency.
#
# Python has a symple syntax that makes it easy to read and write which reduce development time and allows faster project execution.
#
# Python has a rich ecosystem of libraries and frameworks (like NumPy, pandas, Flask, Django, and TensorFlow) that facilitate rapid development and provide tools for various domains, including web development, data science, machine learning, and more.
#
# Python is often used for scripting and automation tasks, making it an invaluable tool for system administrators and developers who want to automate repetitive tasks.
#
# Python can be used for web development, data analysis, machine learning, automation and more.

# %% [raw]
# 2. Describe the role of predefined keywords in Python and provide examples of how they are used in a program.

# %% [raw]
# Ans: Predefined keywords in Python are special reserved words that have specific meanings and cannot be used as variable names or identifiers. They define the syntax and structure of the language, allowing you to perform various operations like control flow, data manipulation, and more. Here's an overview of some key keywords and how they are used in Python programs:
#
# 1: if, elif, else: Used for conditional statements.
# x = 10
# if x > 0:
#     print("Positive number")
# elif x == 0:
#     print("Zero")
# else:
#     print("Negative number")
#
# 2: for, while: Used for loops.
# for i in range(5):
#     print(i)
#
# 3: import: Used to include external modules or libraries.
# import math
# print(math.sqrt(16))

# %% [raw]
# 3: Compare and contrast mutable and immutable objects in Python with examples.

# %% [raw]
# Ans: In Python, objects can be classified as mutable or immutable based on whether they can be changed after they are created.
#
# Changeability:
# Mutable objects can be changed (like lists and dictionaries).
# Immutable objects cannot be changed (like strings and tuples).
#
# Memory:
# Modifying a mutable object does not create a new object; it changes the existing one.
# Modifying an immutable object creates a new object in memory.
#
# Use Cases:
# Use mutable objects when you need to change data frequently.
# Use immutable objects when you want to ensure that the data remains constant.
#
# In summary, mutable objects in Python can be changed after creation, while immutable objects cannot. Lists and dictionaries are examples of mutable objects, whereas strings and tuples are examples of immutable objects.

# %% [raw]
# 4. Discuss the different types of operators in Python and provide examples of how they are used.

# %% [raw]
# Ans: Python provides several types of operators to perform operations on variables and values. Here’s a summary:
#
# 1. Arithmetic Operators
# Used for basic math operations:
# +: Addition
# -: Subtraction
# *: Multiplication
# /: Division
# //: Floor Division
# %: Modulus (remainder)
# **: Exponentiation (power)
#
# 2. Comparison Operators
# Used to compare values:
# ==: Equal
# !=: Not Equal
# >: Greater Than
# <: Less Than
# >=: Greater Than or Equal To
# <=: Less Than or Equal To
#
# 3. Logical Operators
# Used to combine conditional statements:
# and: True if both conditions are true
# or: True if at least one condition is true
# not: Reverses the truth value
#
# 4. Assignment Operators
# Used to assign values to variables:
# =: Simple assignment
# +=: Add and assign
# -=: Subtract and assign
# *=: Multiply and assign
# /=: Divide and assign
#
# 5. Identity Operators
# Check if two variables point to the same object:
# is: True if both variables refer to the same object
# is not: True if they do not refer to the same object

# %% [raw]
# 5. Explain the concept of type casting in Python with examples.

# %% [raw]
# Type Casting in Python
# Type casting is the process of converting a variable from one data type to another. In Python, this can be necessary for various operations that require specific types.
#
# Types of Type Casting
# 1. Implicit Type Casting (Automatic)
# Python automatically converts one data type to another when required, particularly during operations that involve mixed types.
# Example:
# a = 5       # integer
# b = 2.0     # float
# result = a + b  # a is automatically converted to float
# print(result)  # Output: 7.0
#
# 2. Explicit Type Casting (Manual)
# We can manually convert a variable from one type to another using built-in functions.
#
# Common Type Casting Functions:
# int(): Converts to an integer
# float(): Converts to a float
# str(): Converts to a string
# Examples:
#
# Integer to Float
# x = 5
# y = float(x)  # Converts integer to float
# print(y)  # Output: 5.0
#
# Float to Integer
# x = 5.7
# y = int(x)  # Converts float to integer (truncates)
# print(y)  # Output: 5
#
# Integer to String
# x = 10
# y = str(x)  # Converts integer to string
# print(y)  # Output: "10"
#
# String to Integer
# x = "20"
# y = int(x)  # Converts string to integer
# print(y)  # Output: 20
#
# String to Float
# x = "3.14"
# y = float(x)  # Converts string to float
# print(y)  # Output: 3.14

# %% [raw]
# 6. How do conditional statements work in Python? Illustrate with examples

# %% [raw]
# Conditional Statements in Python
#
# Conditional statements in Python allow us to execute certain blocks of code based on specific conditions.
# The most common conditional statements are `if`, `elif`, and `else`. Here’s how they work:
#
# Basic Structure
#
# 1. if : Checks a condition and executes a block of code if the condition is true.
# 2. elif (else if) : Allows you to check multiple conditions. It executes a block of code if its condition is true and the previous `if` conditions were false.
# 3.else : Executes a block of code if none of the preceding conditions were true.
#
# Example 1: Basic if Statement
#
# age = 18
#
# if age >= 18:
#     print("You are an adult.")
#
# input : 21
#
# Output: You are an adult.
#
# Example 2: if with else
#
# age = 16
#
# if age >= 18:
#     print("You are an adult.")
# else:
#     print("You are a minor.")
#
# input : 17
#
# Output: You are a minor.
#
# Example 3: Using `elif`
#
# age = 20
#
# if age < 13:
#     print("You are a child.")
# elif age < 18:
#     print("You are a teenager.")
# else:
#     print("You are an adult.")
#
# input : 22
#
# Output: `You are an adult.
#
# Example 4: Multiple Conditions
#
# You can also use logical operators to combine conditions:
#
# temperature = 30
#
# if temperature > 30:
#     print("It's hot outside.")
# elif temperature >= 20 and temperature <= 30:
#     print("The weather is pleasant.")
# else:
#     print("It's cold outside.")
#
# Output: `The weather is pleasant.`
#
# Example 5: Nested Conditional Statements
#
# We can nest conditional statements to create more complex logic:
#
# num = 10
#
# if num >= 0:
#     if num == 0:
#         print("The number is zero.")
#     else:
#         print("The number is positive.")
# else:
#     print("The number is negative.")
#
# input : -1
#
# Output: `The number is positive.`
#
# Conditional statements in Python help you control the flow of your program by executing different blocks of code based on specific conditions. They are essential for making decisions and handling various scenarios in your code.

# %% [raw]
# 7. Describe the different types of loops in Python and their use cases with examples.

# %% [raw]
# Python has a few different types of loops, including for loops, while loops, nested loops, and statements like break and continue:
#
# For loops: Used to iterate over a sequence, such as a list, tuple, set, dictionary, or string. For loops are used when you know how many times the loop will execute. You can use the built-in range() function to specify a range of objects to print out or to make the for loop run for a specific number of times.
# Example:
# fruits = ["apple", "banana", "cherry"]
# for fruit in fruits:
#     print(fruit)
#
# Output:
# apple
# banana
# cherry
#
# While loops: Used to execute a set of statements repeatedly until a specific condition is met. While loops are used when you don't know how many times the loop will execute, but want to continue until a certain condition is not true.
# Example:
# count = 0
# while count < 5:
#     print(count)
#     count += 1
#
# Output:
# 0
# 1
# 2
# 3
# 4
#
# Nested loops: A loop inside another loop.
#
# Break statements: Terminates the loop containing the break statement and passes control to the statements after the break statement.
# Continue statements: Skips the remaining code inside a loop for the current iteration only
